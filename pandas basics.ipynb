# %%
import pandas as pd

# %%
import numpy as np
data = np.array(['g', 'e', 'e', 'k', 's'])
s = pd.Series(data)
print("Pandas Series:")
print(s)
# Out:
# Pandas Series:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
df = pd.DataFrame() 
print(df)
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks'] 
df = pd.DataFrame(lst) 
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
print(df.isnull().sum())
df = df.fillna(0)
# Out:
# 0    0
# dtype: int64
